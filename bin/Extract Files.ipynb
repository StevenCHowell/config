# %% [markdown]
# For extracting zip files

# %%
import glob

# %%
files = glob.glob('*.zip')
print(len(files))
# Out:
# 79

# %%
cwd = !pwd
cwd
# Out:
# ['/home/schowell/data/torrents/music']

# %%
# !cd {cwd[0]}
# !pwd
# Out:
# /home/schowell/data/torrents/music

# %%
for i, file in enumerate(files):
    path = 'tmp{:02}'.format(i)
    # !mkdir {path}
    # !unzip -d {path} {file}
# Out:
# Archive:  thecave_ost_mp3_1396566175.zip
#    creating: tmp00/The Cave Original Soundtrack/
#   inflating: tmp00/The Cave Original Soundtrack/01 Main Title.mp3
#   inflating: tmp00/The Cave Original Soundtrack/02 Enter Scientist.mp3
#   inflating: tmp00/The Cave Original Soundtrack/03 Nuclear Launch Detected.mp3
#   inflating: tmp00/The Cave Original Soundtrack/04 Dragon Rampage.mp3
#   inflating: tmp00/The Cave Original Soundtrack/05 Enter The Twins.mp3
#   inflating: tmp00/The Cave Original Soundtrack/06 Hillbilly Seven Eights.mp3
#   inflating: tmp00/The Cave Original Soundtrack/07 Hillbilly Burns.mp3
#   inflating: tmp00/The Cave Original Soundtrack/08 The Poison.mp3
#   inflating: tmp00/The Cave Original Soundtrack/09 Enter Spooky.mp3
#   inflating: tmp00/The Cave Original Soundtrack/10 The Waterfall.mp3
#   inflating: tmp00/The Cave Original Soundtrack/11 Enter The Adventurer.mp3
#   inflating: tmp00/The Cave Original Soundtrack/12 Enter The Time Traveller.mp3
# ...

# %%
print('tmp{:02}'.format(10))
# Out:
# tmp10
